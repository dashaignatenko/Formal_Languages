# %% [markdown]
# ## Синтаксис финитной клаузы чукотского языка
#
# ### основные конструкции: эргативность, косвенные падежи, номинатив
# NB без инкорпорации
# lab_2
#
#
# Даша Игнатенко
#
# G = {N, Σ, P, E}
#
# E = CP
#
# N = {CP, TP, vPitr, vPtr, VPtr, VPitr, NPnom, NPerg, NPobl, Vtr, Vitr, Adv, Adj, Dem, Postp, Nnom, Nobl, Nerg, Ngen}
#
# Σ = {ŋinqej, ətɬa, kojŋə-n, ʔəttʔə-qej, kowɬ-orw-oor,
# ətɬʔa-ta, ʔəttʔə-qaj-a,
# ʔəttʔə-qej-e, ŋenqaj-etə, majŋə-ramajə-k,
# tʔarmas-aʔasek-en,
# nə-mejəŋ-qin, nə-ɣtin-qin,
# ŋotqen, qasa,
# rəɬʔeten-nin ɣa-peɬa-ɬen, ne-nɬʔeten-mək, ɬʔu-ni-n.
# pəkir-ɣʔ-i , simet-ɣʔ-i, piŋku-sit-ɣʔ-i, ɣe-wʔej-ɣərki-ɬin,
# eqeɬpe, n-urʔe-w}
#
# P = {
#
# CP → TP
#
# TP → vPitr | vPtr | nPnom vPitr | NPerg vPtr | vPitr nPnom | vPtr NPerg
#
# vPtr → VPtr | Adv VPtr | VPitr Adv
#
# VPtr → Vtr | nPnom Vtr | nPnom Vtr NPobl | Vtr nPnom | Vtr NPobl
#
# vPitr → VPitr | Adv VPitr | VPitr Adv
#
# VPitr → Vitr | Vitr NPobl | Vitr NPobl NPobl
#
# NPobl → Nobl Postp | Nobl
#
# NPerg → Nerg | Dem Nerg
#
# nPnom → NPnom | Dem NPnom
#
# NPnom → Nnom | Ngen Nnom | Nnom Ngen | Adj NPnom | NPnom | CPrel NPnom | NPnom CPrel
#
# CPrel → VPrel | Adv VPrel | VPrel Adv
#
# VPrel → Vrel | Vrel NPobl | Vrel NPobl NPobl
#
# }
#
#
# ** NB прилагательные бывают только в nPnom, потому что в остальных падежах они инкорпорируются
#
# Nnom → ŋinqej | kowɬ-orw-oor | ətɬa | ʔəttʔə-qej | kojŋə-n
#
# Nerg → ətɬʔa-ta | ʔəttʔə-qaj-a
#
# Nobl → majŋə-ramajə-k | ŋenqaj-etə | ʔəttʔə-qej-e
#
# Ngen → tʔarmas-aʔasek-en
#
# Vtr → ne-nɬʔeten-mək | rəɬʔeten-nin | ɬʔu-ni-n | ɣa-peɬa-ɬen
#
# Vitr → pəkir-ɣʔ-i
#
# Vrel → kojŋə-n-təmn-atə-ɬʔə-n
#
# Adv → eqeɬpe | n-urʔe-w
#
# Adj → nə-mejəŋ-qin | nə-ɣtin-qin | simet-ɣʔ-i | piŋku-sit-ɣʔ-i | ɣe-wʔej-ɣərki-ɬin
#
# Dem → ŋotqen
#
# Postp → qasa
#
#
# ### Примеры:
#
# ne-nɬʔeten-mək
# ‘Он нас отвез’
#
# CP → TP → vPtr → VPtr → Vtr
#
#
# ŋinqej rəɬʔeten-nin majŋə-ramajə-k ətɬʔa-ta
#
# Nnom’мальчик’ Vtr’отвезла’ Nobl’в.большой.поселок’ Nerg’мать’
#
# ‘Мама отвезла мальчика в большой посёлок’
#
# CP → TP → vPtr NPerg → nPnom Vtr NPobl NPerg → NPnom Vtr NPobl NPerg → Nnom Vtr NPobl NPerg
#
#
# ʔəttʔə-qaj-a ŋotqen nə-mejəŋ-qin kowɬ-orw-oor ɬʔu-ni-n
#
# Nerg’собачка’ Dem’этот’ Adj’большой’ Nnom’машина’ Vtr’увидел’
#
# ‘Cобака увидела эту большую машину’
#
# CP → TP → NPerg vPtr → NPerg nPnom Vtr → Nerg Dem NPnom Vtr → Nerg Dem Adj NPnom Vtr → NPerg Dem Adj Nnom Vtr
#
#
# ʔəttʔə-qaj-a ɣa-peɬa-ɬen ŋotqen eqeɬpe kojŋə-n-təmn-atə-ɬʔə-n ətɬa tʔarmas-aʔasek-en
#
# Nerg’собачка’ Vtr’оставил’ Dem’этот’ Adv’быстро’ Vrel’разбивший.чашку’ Nnom’мать’ Ngen’мальчика.забияки
#
# ‘Собака оставила эту маму мальчика-забияки, быстро потерявшую чашку’
#
# CP → TP → NPerg vPtr → NPerg VPtr → Nerg Vtr nPnom → Nerg Vtr Dem NPnom → Nerg Vtr Dem CPrel NPnom → Nerg Vtr Dem Adv VPrel NPnom → Nerg Vtr Dem Adv Vrel Nnom Ngen
#
#
# pəkir-ɣʔ-i ŋenqaj-etə majŋə-ramajə-k
#
# Vitr’приехал’ Nobl’к.мальчику’ Nobl’в.поселок’
#
# ‘Он приехал к мальчику в посёлок’
#
# CP → TP → vPitr → VPitr → Vitr NPobl NPobl

# %%
import nltk
from nltk import Nonterminal, nonterminals, Production, CFG
from nltk.grammar import FeatureGrammar as FCFG
from nltk.tree import Tree
import svgling

# %%
CP, TP, vPitr, vPtr, VPtr, VPitr, NPnom, NPerg, NPobl, Vtr, Vitr, Adv, Adj, Dem, Postp, Nnom, Nobl, Nerg, Ngen = nonterminals('CP, TP, vPitr, vPtr, VPtr, VPitr, NPnom, NPerg, NPobl, Vtr, Vitr, Adv, Adj, Dem, Postp, Nnom, Nobl, Nerg, Ngen')

# %%
grammar = CFG.fromstring("""
CP -> TP
TP -> vPitr | vPtr | nPnom vPitr | NPerg vPtr | vPitr nPnom | vPtr NPerg
vPtr -> VPtr | Adv VPtr | VPitr Adv
VPtr -> Vtr | nPnom Vtr | nPnom Vtr NPobl | Vtr nPnom | Vtr NPobl
vPitr -> VPitr | Adv VPitr | VPitr Adv
VPitr -> Vitr | Vitr NPobl | Vitr NPobl NPobl
NPobl -> Nobl Postp | Nobl
NPerg -> Nerg | Dem Nerg
nPnom -> NPnom | Dem NPnom
NPnom -> Nnom | Ngen Nnom | Nnom Ngen | Adj NPnom  | CPrel NPnom | NPnom CPrel
CPrel -> VPrel | Adv VPrel | VPrel Adv
VPrel -> Vrel | Vrel NPobl | Vrel NPobl NPobl
Nnom -> 'ŋinqej' | 'kowɬ-orw-oor' | 'ətɬa' | 'ʔəttʔə-qej' | 'kojŋə-n'
Nerg -> 'ətɬʔa-ta' | 'ʔəttʔə-qaj-a'
Nobl -> 'majŋə-ramajə-k' | 'ŋenqaj-etə' | 'ʔəttʔə-qej-e'
Ngen -> 'tʔarmas-aʔasek-en'
Vtr -> 'ne-nɬʔeten-mək' | 'rəɬʔeten-nin' | 'ɬʔu-ni-n' | 'ɣa-peɬa-ɬen'
Vitr -> 'pəkir-ɣʔ-i'
Vrel -> 'kojŋə-n-təmn-atə-ɬʔə-n'
Adv -> 'eqeɬpe' | 'n-urʔe-w'
Adj -> 'nə-mejəŋ-qin' | 'nə-ɣtin-qin' | 'simet-ɣʔ-i' | 'piŋku-sit-ɣʔ-i' | 'ɣe-wʔej-ɣərki-ɬin'
Dem -> 'ŋotqen'
Postp -> 'qasa'
""")

# %%
print(grammar)
# Out:
# Grammar with 65 productions (start state = CP)
#     CP -> TP
#     TP -> vPitr
#     TP -> vPtr
#     TP -> nPnom vPitr
#     TP -> NPerg vPtr
#     TP -> vPitr nPnom
#     TP -> vPtr NPerg
#     vPtr -> VPtr
#     vPtr -> Adv VPtr
#     vPtr -> VPitr Adv
#     VPtr -> Vtr
#     VPtr -> nPnom Vtr
#     VPtr -> nPnom Vtr NPobl
#     VPtr -> Vtr nPnom
#     VPtr -> Vtr NPobl
#     vPitr -> VPitr
#     vPitr -> Adv VPitr
#     vPitr -> VPitr Adv
#     VPitr -> Vitr
#     VPitr -> Vitr NPobl
#     VPitr -> Vitr NPobl NPobl
#     NPobl -> Nobl Postp
#     NPobl -> Nobl
#     NPerg -> Nerg
#     NPerg -> Dem Nerg
#     nPnom -> NPnom
#     nPnom -> Dem NPnom
#     NPnom -> Nnom
#     NPnom -> Ngen Nnom
#     NPnom -> Nnom Ngen
#     NPnom -> Adj NPnom
#     NPnom -> CPrel NPnom
#     NPnom -> NPnom CPrel
#     CPrel -> VPrel
#     CPrel -> Adv VPrel
#     CPrel -> VPrel Adv
#     VPrel -> Vrel
#     VPrel -> Vrel NPobl
#     VPrel -> Vrel NPobl NPobl
#     Nnom -> 'ŋinqej'
# ...

# %%
def parse_chkt(sents, grammar):
    cp = nltk.parse.ChartParser(grammar)
    ts = ['ŋinqej', 'ətɬa', 'kojŋə-n', 'ʔəttʔə-qej', 'kowɬ-orw-oor', 'ətɬʔa-ta', 
          'ʔəttʔə-qaj-a', 'ʔəttʔə-qej-e', 'ŋenqaj-etə', 'majŋə-ramajə-k', 'tʔarmas-aʔasek-en', 
          'nə-mejəŋ-qin', 'nə-ɣtin-qin', 'ŋotqen', 'qasa', 'rəɬʔeten-nin', 'ɣa-peɬa-ɬen', 'ne-nɬʔeten-mək', 'kojŋə-n-təmn-atə-ɬʔə-n',
          'ɬʔu-ni-n', 'pəkir-ɣʔ-i', 'simet-ɣʔ-i', 'piŋku-sit-ɣʔ-i', 'ɣe-wʔej-ɣərki-ɬin', 'eqeɬpe', 'n-urʔe-w']
    res = {}
    for i in sents:
        res[i] = []
        sent = i.split()
        print(i + '\n')
        if all(w in ts for w in sent) == False:
            print('\nUnrecognized words')
        else: 
            for x in cp.parse(sent):
                res[i].append(x)
    return res

# %%
sents = ['ʔəttʔə-qaj-a ŋotqen nə-mejəŋ-qin kowɬ-orw-oor ɬʔu-ni-n', 'ŋinqej rəɬʔeten-nin majŋə-ramajə-k ətɬʔa-ta', 'ʔəttʔə-qaj-a ɣa-peɬa-ɬen ŋotqen eqeɬpe kojŋə-n-təmn-atə-ɬʔə-n ətɬa tʔarmas-aʔasek-en', 'pəkir-ɣʔ-i ŋenqaj-etə majŋə-ramajə-k']
res = parse_chkt(sents, grammar)
# Out:
# ʔəttʔə-qaj-a ŋotqen nə-mejəŋ-qin kowɬ-orw-oor ɬʔu-ni-n
#
# ŋinqej rəɬʔeten-nin majŋə-ramajə-k ətɬʔa-ta
#
# ʔəttʔə-qaj-a ɣa-peɬa-ɬen ŋotqen eqeɬpe kojŋə-n-təmn-atə-ɬʔə-n ətɬa tʔarmas-aʔasek-en
#
# pəkir-ɣʔ-i ŋenqaj-etə majŋə-ramajə-k

# %%
res[sents[1]]
# Out:
# [Tree('CP', [Tree('TP', [Tree('vPtr', [Tree('VPtr', [Tree('nPnom', [Tree('NPnom', [Tree('Nnom', ['ŋinqej'])])]), Tree('Vtr', ['rəɬʔeten-nin']), Tree('NPobl', [Tree('Nobl', ['majŋə-ramajə-k'])])])]), Tree('NPerg', [Tree('Nerg', ['ətɬʔa-ta'])])])])]

# %% [markdown]
# Функция, анализирующая распраршеное предложение: строит дерево, проверяет переходность, находит подлежащее

# %%
def analyse_parsed(sents, res):
    an = ''
    for i in sents:
        for tree in res[i]:
            tree.pretty_print()
            trans = ''
            if len(tree[0]) == 2:
                if tree[0][1].label() == 'vPtr' or tree[0][0].label() == 'vPtr':
                    print('Предложение переходное\n')
                    trans = 'tr'
                elif tree[0][1].label() == 'vPitr' or tree[0][0].label() == 'vPitr':
                    print('Предложение непереходное\n')
                    trans = 'itr'
            else:
                if tree[0][0].label() == 'vPtr':
                    print('Предложение переходное\n')
                    trans = 'tr'
                elif tree[0][0].label() == 'vPitr':
                    print('Предложение непереходное\n')
                    trans = 'itr'
            subj = ''
            if trans == 'tr':
                for subtree in tree.subtrees():
                    if subtree.label() == 'Nerg':
                        subj = ' '.join(subtree.leaves())
            if trans == 'itr':
                for subtree in tree.subtrees():
                    if subtree.label() == 'Nnom':
                        subj = ' '.join(subtree.leaves())
            if subj == '':
                print('Подлежащее не выражено')
            else:
                print("Подлежащее: ", subj)

# %%
analyse_parsed(sents, res)
# Out:
#                          CP
#                          |
#                          TP
#       ___________________|_________
#      |                            vPtr
#      |                             |
#      |                            VPtr
#      |                    _________|___________________
#      |                 nPnom                           |
#      |          _________|_________                    |
#      |         |                 NPnom                 |
#      |         |          _________|________           |
#    NPerg       |         |                NPnom        |
#      |         |         |                  |          |
#     Nerg      Dem       Adj                Nnom       Vtr
#      |         |         |                  |          |
# ʔəttʔə-qaj-a ŋotqen nə-mejəŋ-qin       kowɬ-orw-oor ɬʔu-ni-n
#
# Предложение переходное
#
# Подлежащее:  ʔəttʔə-qaj-a
#                      CP
#                      |
#                      TP
# ...
